# %% [markdown]
# # Exploratory Data Analysis to figure out which variables have direct and clear impact on employee Retention

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\Tahir Mehmood\Downloads\Compressed\archive_4\HR_comma_sep.csv')
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.head(10)
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
# 5                0.41             0.50               2                   153
# 6                0.10             0.77               6                   247
# 7                0.92             0.85               5                   259
# 8                0.89             1.00               5                   224
# 9                0.42             0.53               2                   142
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# ...

# %%
# %matplotlib inline
plt.scatter(df.satisfaction_level, df.left)
plt.xlabel('Satisfaction Level')
plt.ylabel('Left Company')
# Out:
# Text(0, 0.5, 'Left Company')

# %%
plt.scatter(df.last_evaluation, df.left)
plt.xlabel('Last Evaluation')
plt.ylabel('Left Company')
# Out:
# Text(0, 0.5, 'Left Company')

# %%
plt.scatter(df.number_project, df.left)
plt.xlabel('Number of Projects')
plt.ylabel('Left Company')
# Out:
# Text(0, 0.5, 'Left Company')

# %%
plt.scatter(df.average_montly_hours, df.left)
plt.xlabel('Average Monthly Hours')
plt.ylabel('Left Company')
# Out:
# Text(0, 0.5, 'Left Company')

# %%
plt.scatter(df.time_spend_company, df.left)
plt.xlabel('Time Spend Company')
plt.ylabel('Left Company')
# Out:
# Text(0, 0.5, 'Left Company')

# %%
plt.scatter(df.Work_accident, df.left)
plt.xlabel('Work Accident')
plt.ylabel('Left Company')
# Out:
# Text(0, 0.5, 'Left Company')

# %%
plt.scatter(df.promotion_last_5years, df.left)
plt.xlabel('Promotion Last 5 Year')
plt.ylabel('Left Company')
# Out:
# Text(0, 0.5, 'Left Company')

# %%
pd.crosstab(df.Department,df.left).plot(kind='bar')
# Out:
# <Axes: xlabel='Department'>

# %%
pd.crosstab(df.salary,df.left).plot(kind='bar')
# Out:
# <Axes: xlabel='salary'>

# %%
left = df[df.left == 1]
left
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
retained = df[df.left==0]
retained
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 2000                 0.58             0.74               4
# 2001                 0.82             0.67               2
# 2002                 0.45             0.69               5
# 2003                 0.78             0.82               5
# 2004                 0.49             0.60               3
# ...                   ...              ...             ...
# 14206                0.90             0.55               3
# 14207                0.74             0.95               5
# 14208                0.85             0.54               3
# 14209                0.33             0.65               3
# 14210                0.50             0.73               4
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 2000                    215                   3              0     0
# 2001                    202                   3              0     0
# ...

# %%
df1 = df[['satisfaction_level','last_evaluation','number_project','average_montly_hours','time_spend_company','Work_accident','left','promotion_last_5years']]
df1.groupby('left').mean()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# left
# 0               0.666810         0.715473        3.786664
# 1               0.440098         0.718113        3.855503
#
#       average_montly_hours  time_spend_company  Work_accident  \
# left
# 0               199.060203            3.380032       0.175009
# 1               207.419210            3.876505       0.047326
#
#       promotion_last_5years
# left
# 0                  0.026251
# 1                  0.005321

# %% [markdown]
# #### From Above Analysis it is cleared that these are the factors whicha are affecting the employee retention:
#     1. Satisfaction Level
#     2. Average Monthly Hours
#     3. Work Accident
#     4. Promotion Last 5 years
#     5. Salary

# %%
dummies = pd.get_dummies(df.salary, prefix = 'salary', dtype = int)
dummies
# Out:
#        salary_high  salary_low  salary_medium
# 0                0           1              0
# 1                0           0              1
# 2                0           0              1
# 3                0           1              0
# 4                0           1              0
# ...            ...         ...            ...
# 14994            0           1              0
# 14995            0           1              0
# 14996            0           1              0
# 14997            0           1              0
# 14998            0           1              0
#
# [14999 rows x 3 columns]

# %%
df2 = pd.concat([df,dummies],axis = 'columns')
df2
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
x = df2.drop(['last_evaluation', 'number_project','time_spend_company','Department', 'salary','left'], axis = 'columns')
x
# Out:
#        satisfaction_level  average_montly_hours  Work_accident  \
# 0                    0.38                   157              0
# 1                    0.80                   262              0
# 2                    0.11                   272              0
# 3                    0.72                   223              0
# 4                    0.37                   159              0
# ...                   ...                   ...            ...
# 14994                0.40                   151              0
# 14995                0.37                   160              0
# 14996                0.37                   143              0
# 14997                0.11                   280              0
# 14998                0.37                   158              0
#
#        promotion_last_5years  salary_high  salary_low  salary_medium
# 0                          0            0           1              0
# 1                          0            0           0              1
# ...

# %%
y = df.left
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14994    1
# 14995    1
# 14996    1
# 14997    1
# 14998    1
# Name: left, Length: 14999, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test, y_train, y_test = train_test_split(x,y,test_size = 0.3)

# %%
x_train
# Out:
#        satisfaction_level  average_montly_hours  Work_accident  \
# 395                  0.45                   128              0
# 5105                 0.49                   246              0
# 3084                 0.34                   152              1
# 13371                0.74                   136              0
# 5111                 0.52                   148              0
# ...                   ...                   ...            ...
# 9209                 0.84                   118              0
# 1014                 0.44                   156              0
# 8971                 0.58                   287              0
# 9071                 0.96                   244              1
# 5552                 0.87                   256              0
#
#        promotion_last_5years  salary_high  salary_low  salary_medium
# 395                        0            0           1              0
# 5105                       0            0           1              0
# ...

# %%
x_test
# Out:
#        satisfaction_level  average_montly_hours  Work_accident  \
# 11366                0.76                   217              0
# 14905                0.11                   247              0
# 2064                 0.86                   147              0
# 8030                 0.76                   172              0
# 11584                0.65                   233              1
# ...                   ...                   ...            ...
# 13228                0.73                   233              1
# 10837                0.86                   251              0
# 7717                 0.14                   226              0
# 2699                 0.30                   276              1
# 8197                 0.51                   223              1
#
#        promotion_last_5years  salary_high  salary_low  salary_medium
# 11366                      0            0           0              1
# 14905                      0            0           0              1
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression( max_iter=1000)

# %%
from sklearn.preprocessing import StandardScaler

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
model.predict(x_test)
# Out:
# array([0, 1, 0, ..., 1, 0, 0], dtype=int64)

# %%
model.score(x_test,y_test)
# Out:
# 0.7822222222222223
